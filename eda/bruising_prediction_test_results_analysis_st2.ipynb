# %% [markdown]
# # Bruising Prediction CNN Test Result Analysis
#
# Adapted from `/home/emahan/sysops/HIPPA/hanif/cnn/cnn_test_results_analysis.ipynb` for the bruising detection project outputs.
#
# This notebook analyzes `reports/tables/cnn_test_predictions.csv`, summarizes train/validation/test splits, computes overall and grouped metrics, plots confusion matrices, compares warm/cold conditions, compares impact groups, and lists incorrect predictions for inspection.

# %%
from pathlib import Path
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support

PROJECT_ROOT = Path('/home/emahan/sysops/HIPPA/hanif/bruising_detection')
TABLE_DIR = PROJECT_ROOT / 'reports' / 'tables'
FIGURE_DIR = PROJECT_ROOT / 'reports' / 'figures'
REPO_FIGURE_DIR = PROJECT_ROOT / 'figures'
PREDICTIONS_CSV = TABLE_DIR / 'cnn_test_predictions.csv'
LABELS = [0, 1]
LABEL_NAMES = ['sound', 'bruised']

FIGURE_DIR.mkdir(parents=True, exist_ok=True)
REPO_FIGURE_DIR.mkdir(parents=True, exist_ok=True)


def save_figure(fig, filename: str):
    fig.savefig(FIGURE_DIR / filename, dpi=200, bbox_inches='tight')
    fig.savefig(REPO_FIGURE_DIR / filename, dpi=200, bbox_inches='tight')

df = pd.read_csv(PREDICTIONS_CSV)
df['sample_id'] = df['file'].astype(str) + ' | ' + df['timepoint'].astype(str) + ' | ' + df['dataset'].astype(str)
df['microtec_id'] = df['file'].str.extract(r'MICROTEC_(\d+)')[0]
df['prefix2'] = df['microtec_id'].str[:2]
df['prefix3'] = df['microtec_id'].str[:3]
df['correct'] = df['y_true'].eq(df['y_pred'])

display(df.head())
print('Rows:', len(df))
print('Timepoints:', sorted(df['timepoint'].astype(str).unique()))
print('Files:', df['file'].nunique())
# Out:
#                                                 path  \
# 0  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
# 1  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
# 2  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
# 3  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
# 4  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
#
#                                 file    group timepoint   dataset  y  label  \
# 0  MICROTEC_29405_processed_boxes.h5  SWIR_t0        t0  bruised1  0  sound
# 1  MICROTEC_29405_processed_boxes.h5  SWIR_t0        t0  bruised2  0  sound
# 2  MICROTEC_29405_processed_boxes.h5  SWIR_t0        t0  bruised3  0  sound
# 3  MICROTEC_29405_processed_boxes.h5  SWIR_t0        t0  bruised4  0  sound
# 4  MICROTEC_29405_processed_boxes.h5  SWIR_t0        t0    sound1  0  sound
#
#     box_shape  crop_shape  bands  y_true  y_pred y_true_label y_pred_label  \
# 0  (160, 160)  (160, 160)    220       0       0        sound        sound
# 1  (160, 160)  (160, 160)    220       0       0        sound        sound
# 2  (160, 160)  (160, 160)    220       0       0        sound        sound
# 3  (160, 160)  (160, 160)    220       0       0        sound        sound
# 4  (160, 160)  (160, 160)    220       0       0        sound        sound
#
#                                            sample_id microtec_id prefix2  \
# 0  MICROTEC_29405_processed_boxes.h5 | t0 | bruised1       29405      29
# 1  MICROTEC_29405_processed_boxes.h5 | t0 | bruised2       29405      29
# 2  MICROTEC_29405_processed_boxes.h5 | t0 | bruised3       29405      29
# 3  MICROTEC_29405_processed_boxes.h5 | t0 | bruised4       29405      29
# 4    MICROTEC_29405_processed_boxes.h5 | t0 | sound1       29405      29
#
#   prefix3  correct
# 0     294     True
# 1     294     True
# 2     294     True
# 3     294     True
# 4     294     True
# Rows: 384
# Timepoints: ['t0', 't1', 't2', 't3']
# Files: 12

# %% [markdown]
# ## Train/Validation/Test Sample Counts
#
# This block uses the saved project split sample CSVs in `data/splits`, so it reports the exact split files used by the current project results.

# %%
SPLIT_SAMPLE_CSVS = {
    'train': PROJECT_ROOT / 'data' / 'splits' / 'train_samples.csv',
    'val': PROJECT_ROOT / 'data' / 'splits' / 'val_samples.csv',
    'test': PROJECT_ROOT / 'data' / 'splits' / 'test_samples.csv',
}

split_rows = []
for split, path in SPLIT_SAMPLE_CSVS.items():
    split_df = pd.read_csv(path)
    split_rows.append({
        'split': split,
        'n_files': split_df['file'].nunique(),
        'n_samples': len(split_df),
        'n_sound': int((split_df['y'] == 0).sum()),
        'n_bruised': int((split_df['y'] == 1).sum()),
    })

split_summary = pd.DataFrame(split_rows)
total_files = int(split_summary['n_files'].sum())
total_samples = int(split_summary['n_samples'].sum())
total_sound = int(split_summary['n_sound'].sum())
total_bruised = int(split_summary['n_bruised'].sum())
split_summary['file_ratio'] = (split_summary['n_files'] / total_files).round(4)
split_summary['sample_ratio'] = (split_summary['n_samples'] / total_samples).round(4)
split_summary = pd.concat([
    split_summary,
    pd.DataFrame([{
        'split': 'total',
        'n_files': total_files,
        'n_samples': total_samples,
        'n_sound': total_sound,
        'n_bruised': total_bruised,
        'file_ratio': 1.0,
        'sample_ratio': 1.0,
    }]),
], ignore_index=True)

display(split_summary)
split_summary.to_csv(TABLE_DIR / 'bruising_prediction_split_sample_summary.csv', index=False)
# Out:
#    split  n_files  n_samples  n_sound  n_bruised  file_ratio  sample_ratio
# 0  train       94       3008     1880       1128      0.7966        0.7966
# 1    val       12        384      240        144      0.1017        0.1017
# 2   test       12        384      240        144      0.1017        0.1017
# 3  total      118       3776     2360       1416      1.0000        1.0000

# %%
def metric_row(data, name=None):
    y_true = data['y_true'].to_numpy()
    y_pred = data['y_pred'].to_numpy()
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=LABELS).ravel()
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='binary', zero_division=0)
    row = {
        'n': int(len(data)),
        'correct': int((y_true == y_pred).sum()),
        'incorrect': int((y_true != y_pred).sum()),
        'true_negative': int(tn),
        'false_positive': int(fp),
        'false_negative': int(fn),
        'true_positive': int(tp),
        'n_true_positive_samples': int((y_true == 1).sum()),
        'n_predicted_positive_samples': int((y_pred == 1).sum()),
        'accuracy': round(accuracy_score(y_true, y_pred), 4),
        'precision': round(precision, 4),
        'recall': round(recall, 4),
        'f1': round(f1, 4),
    }
    if name is not None:
        row = {'group': name, **row}
    return row


def metrics_by(data, group_col):
    return pd.DataFrame([metric_row(g, name) for name, g in data.groupby(group_col, sort=True)]).reset_index(drop=True)


def plot_confusion(cm, title, ax=None):
    if ax is None:
        _, ax = plt.subplots(figsize=(4, 3.5))
    im = ax.imshow(cm, cmap='Blues')
    ax.set_title(title)
    ax.set_xticks(range(len(LABEL_NAMES)), LABEL_NAMES)
    ax.set_yticks(range(len(LABEL_NAMES)), LABEL_NAMES)
    ax.set_xlabel('Predicted label')
    ax.set_ylabel('True label')
    threshold = cm.max() / 2 if cm.size and cm.max() else 0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, int(cm[i, j]), ha='center', va='center', color='white' if cm[i, j] > threshold else 'black')
    return im

# %% [markdown]
# ## Overall Confusion Matrix

# %%
overall = pd.DataFrame([metric_row(df, 'overall')])
display(overall)
overall.to_csv(TABLE_DIR / 'bruising_prediction_test_overall_metrics.csv', index=False)

cm = confusion_matrix(df['y_true'], df['y_pred'], labels=LABELS)
fig, ax = plt.subplots(figsize=(4.5, 4))
plot_confusion(cm, 'Overall confusion matrix', ax=ax)
plt.tight_layout()
save_figure(fig, 'bruising_prediction_overall_confusion.png')
plt.show()
# Out:
#      group    n  correct  incorrect  true_negative  false_positive  \
# 0  overall  384      368         16            231               9
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0               7            137                      144
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                           146    0.9583     0.9384  0.9514  0.9448

# %% [markdown]
# ## Accuracy, Precision, Recall by Timepoint

# %%
timepoint_metrics = metrics_by(df, 'timepoint')
display(timepoint_metrics)
timepoint_metrics.to_csv(TABLE_DIR / 'bruising_prediction_test_metrics_by_timepoint.csv', index=False)
# Out:
#   group   n  correct  incorrect  true_negative  false_positive  \
# 0    t0  96       94          2             94               2
# 1    t1  96       89          7             46               2
# 2    t2  96       92          4             46               2
# 3    t3  96       93          3             45               3
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0               0              0                        0
# 1               5             43                       48
# 2               2             46                       48
# 3               0             48                       48
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                             2    0.9792     0.0000  0.0000  0.0000
# 1                            45    0.9271     0.9556  0.8958  0.9247
# 2                            48    0.9583     0.9583  0.9583  0.9583
# 3                            51    0.9688     0.9412  1.0000  0.9697

# %% [markdown]
# ## Confusion Matrix per Timepoint

# %%
timepoints = sorted(df['timepoint'].astype(str).unique())
ncols = 2
nrows = int(np.ceil(len(timepoints) / ncols))
fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4.2 * nrows))
axes = np.atleast_1d(axes).ravel()

for ax, tp in zip(axes, timepoints):
    g = df[df['timepoint'].astype(str) == tp]
    cm = confusion_matrix(g['y_true'], g['y_pred'], labels=LABELS)
    plot_confusion(cm, f"Timepoint {str(tp).lstrip('t')}", ax=ax)

for ax in axes[len(timepoints):]:
    ax.axis('off')

plt.tight_layout()
save_figure(fig, 'bruising_prediction_timepoint_confusion.png')
plt.show()

# %% [markdown]
# ## Comparison: Warm vs Cold Condition
#
# Warm/cold groups are derived from the MICROTEC id prefix in the filename, matching the source notebook logic.

# %%
compare_warm_cold = df[df['prefix2'].isin(['28', '29'])].copy()
compare_warm_cold['comparison_group'] = compare_warm_cold['prefix2'].map({'28': 'warm', '29': 'cold'})
metrics_warm_cold = metrics_by(compare_warm_cold, 'comparison_group')
metrics_warm_cold = metrics_warm_cold.set_index('group').loc[['warm', 'cold']].reset_index()
display(metrics_warm_cold)
metrics_warm_cold.to_csv(TABLE_DIR / 'bruising_prediction_test_compare_warm_cold.csv', index=False)

fig, ax = plt.subplots(figsize=(5.5, 4.0))
bars = ax.bar(metrics_warm_cold['group'], metrics_warm_cold['accuracy'], color=['#d98948', '#4c78a8'])
ax.set_ylim(0, 1)
ax.set_ylabel('Accuracy')
ax.set_title('Warm vs cold condition')
for bar, (_, row) in zip(bars, metrics_warm_cold.iterrows()):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        max(row['accuracy'] - 0.12, 0.08),
        f"{row['correct']}/{row['n']} correct\nacc={row['accuracy']:.3f}",
        ha='center', va='center', color='black', fontsize=10,
        bbox={'facecolor': 'white', 'edgecolor': 'none', 'alpha': 0.85, 'pad': 3},
    )
plt.tight_layout()
save_figure(fig, 'bruising_prediction_warm_cold_accuracy.png')
plt.show()
# Out:
#   group    n  correct  incorrect  true_negative  false_positive  \
# 0  warm  192      183          9            114               6
# 1  cold  192      185          7            117               3
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0               3             69                       72
# 1               4             68                       72
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                            75    0.9531     0.9200  0.9583  0.9388
# 1                            71    0.9635     0.9577  0.9444  0.9510

# %% [markdown]
# ## Comparison: Low, Medium, and High Impact
#
# Impact groups are derived from the first three digits of the MICROTEC id, matching the project EDA grouping.

# %%
low_impact_prefixes = {'280', '281', '290', '291'}
medium_impact_prefixes = {'282', '292', '283', '293'}
high_impact_prefixes = {'284', '285', '294', '295'}


def impact_group(prefix):
    if prefix in low_impact_prefixes:
        return 'low impact'
    if prefix in medium_impact_prefixes:
        return 'medium impact'
    if prefix in high_impact_prefixes:
        return 'high impact'
    return np.nan

compare_impact_groups = df.copy()
compare_impact_groups['comparison_group'] = compare_impact_groups['prefix3'].map(impact_group)
compare_impact_groups = compare_impact_groups.dropna(subset=['comparison_group'])
metrics_impact_groups = metrics_by(compare_impact_groups, 'comparison_group')
metrics_impact_groups = metrics_impact_groups.set_index('group').loc[['low impact', 'medium impact', 'high impact']].reset_index()
display(metrics_impact_groups)
metrics_impact_groups.to_csv(TABLE_DIR / 'bruising_prediction_test_compare_impact_groups.csv', index=False)

fig, ax = plt.subplots(figsize=(6.8, 4.0))
colors = {'low impact': '#9b6fb0', 'medium impact': '#d8a03d', 'high impact': '#6f9e59'}
bars = ax.bar(
    metrics_impact_groups['group'],
    metrics_impact_groups['accuracy'],
    color=[colors[g] for g in metrics_impact_groups['group']],
)
ax.set_ylim(0, 1)
ax.set_ylabel('Accuracy')
ax.set_title('Low, medium, and high impact')
for bar, (_, row) in zip(bars, metrics_impact_groups.iterrows()):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        max(row['accuracy'] - 0.12, 0.08),
        f"{row['correct']}/{row['n']} correct\nacc={row['accuracy']:.3f}",
        ha='center', va='center', color='black', fontsize=10,
        bbox={'facecolor': 'white', 'edgecolor': 'none', 'alpha': 0.85, 'pad': 3},
    )
legend_handles = [plt.Rectangle((0, 0), 1, 1, color=colors[name], label=name) for name in ['low impact', 'medium impact', 'high impact']]
ax.legend(handles=legend_handles, title='Group', loc='center left', bbox_to_anchor=(1.02, 0.5), borderaxespad=0)
plt.tight_layout()
save_figure(fig, 'bruising_prediction_impact_accuracy.png')
plt.show()
# Out:
#            group    n  correct  incorrect  true_negative  false_positive  \
# 0     low impact  128      123          5             80               0
# 1  medium impact  128      122          6             76               4
# 2    high impact  128      123          5             75               5
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0               5             43                       48
# 1               2             46                       48
# 2               0             48                       48
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                            43    0.9609     1.0000  0.8958  0.9451
# 1                            50    0.9531     0.9200  0.9583  0.9388
# 2                            53    0.9609     0.9057  1.0000  0.9505

# %% [markdown]
# ## Comparison: Low, Medium, and High Impact

# %%
low_impact_prefixes = {'280', '281', '290', '291'}
medium_impact_prefixes = {'282', '292', '283', '293'}
high_impact_prefixes = {'284', '285', '294', '295'}


def impact_group_three_level(prefix):
    if prefix in low_impact_prefixes:
        return 'low impact'
    if prefix in medium_impact_prefixes:
        return 'medium impact'
    if prefix in high_impact_prefixes:
        return 'high impact'
    return np.nan

compare_three_groups = df.copy()
compare_three_groups['comparison_group'] = compare_three_groups['prefix3'].map(impact_group_three_level)
compare_three_groups = compare_three_groups.dropna(subset=['comparison_group'])
metrics_three_groups = metrics_by(compare_three_groups, 'comparison_group')
metrics_three_groups = metrics_three_groups.set_index('group').loc[['low impact', 'medium impact', 'high impact']].reset_index()
display(metrics_three_groups)
metrics_three_groups.to_csv(TABLE_DIR / 'bruising_prediction_test_compare_three_impact_groups.csv', index=False)

print('Files per group')
display(compare_three_groups.drop_duplicates('file').groupby(['comparison_group', 'prefix3']).size().rename('n_files').reset_index())

fig, ax = plt.subplots(figsize=(6.8, 4.0))
colors = {'low impact': '#9b6fb0', 'medium impact': '#d8a03d', 'high impact': '#6f9e59'}
bars = ax.bar(
    metrics_three_groups['group'],
    metrics_three_groups['accuracy'],
    color=[colors[g] for g in metrics_three_groups['group']],
)
ax.set_ylim(0, 1)
ax.set_ylabel('Accuracy')
ax.set_title('Low, medium, and high impact')
for bar, (_, row) in zip(bars, metrics_three_groups.iterrows()):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        max(row['accuracy'] - 0.12, 0.08),
        f"{row['correct']}/{row['n']} correct\nacc={row['accuracy']:.3f}",
        ha='center', va='center', color='black', fontsize=10,
        bbox={'facecolor': 'white', 'edgecolor': 'none', 'alpha': 0.85, 'pad': 3},
    )
plt.tight_layout()
save_figure(fig, 'bruising_prediction_three_impact_accuracy.png')
plt.show()
# Out:
#            group    n  correct  incorrect  true_negative  false_positive  \
# 0     low impact  128      123          5             80               0
# 1  medium impact  128      122          6             76               4
# 2    high impact  128      123          5             75               5
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0               5             43                       48
# 1               2             46                       48
# 2               0             48                       48
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                            43    0.9609     1.0000  0.8958  0.9451
# 1                            50    0.9531     0.9200  0.9583  0.9388
# 2                            53    0.9609     0.9057  1.0000  0.9505
# Files per group
#    comparison_group prefix3  n_files
# 0       high impact     284        1
# 1       high impact     285        1
# 2       high impact     294        1
# 3       high impact     295        1
# 4        low impact     280        1
# 5        low impact     281        1
# 6        low impact     290        1
# 7        low impact     291        1
# 8     medium impact     282        1
# 9     medium impact     283        1
# 10    medium impact     292        1
# 11    medium impact     293        1

# %% [markdown]
# ## Incorrect Predictions for Inspection

# %%
errors = df[~df['correct']].copy()
error_columns = ['file', 'microtec_id', 'timepoint', 'dataset', 'y_true_label', 'y_pred_label', 'y_true', 'y_pred']
display(errors[error_columns])
errors[error_columns].to_csv(TABLE_DIR / 'bruising_prediction_test_incorrect_predictions.csv', index=False)
print('Incorrect predictions:', len(errors), 'of', len(df))
# Out:
#                                   file microtec_id timepoint   dataset  \
# 84   MICROTEC_29507_processed_boxes.h5       29507        t2    sound1
# 92   MICROTEC_29507_processed_boxes.h5       29507        t3    sound1
# 139  MICROTEC_29100_processed_boxes.h5       29100        t1  bruised4
# 174  MICROTEC_28305_processed_boxes.h5       28305        t1    sound3
# 182  MICROTEC_28305_processed_boxes.h5       28305        t2    sound3
# 190  MICROTEC_28305_processed_boxes.h5       28305        t3    sound3
# 200  MICROTEC_28009_processed_boxes.h5       28009        t1  bruised1
# 203  MICROTEC_28009_processed_boxes.h5       28009        t1  bruised4
# 208  MICROTEC_28009_processed_boxes.h5       28009        t2  bruised1
# 234  MICROTEC_29006_processed_boxes.h5       29006        t1  bruised3
# 256  MICROTEC_28507_processed_boxes.h5       28507        t0  bruised1
# 268  MICROTEC_28507_processed_boxes.h5       28507        t1    sound1
# 284  MICROTEC_28507_processed_boxes.h5       28507        t3    sound1
# 322  MICROTEC_29309_processed_boxes.h5       29309        t0  bruised3
# 336  MICROTEC_29309_processed_boxes.h5       29309        t2  bruised1
# 362  MICROTEC_29207_processed_boxes.h5       29207        t1  bruised3
#
#     y_true_label y_pred_label  y_true  y_pred
# 84         sound      damaged       0       1
# 92         sound      damaged       0       1
# 139      damaged        sound       1       0
# 174        sound      damaged       0       1
# 182        sound      damaged       0       1
# 190        sound      damaged       0       1
# 200      damaged        sound       1       0
# 203      damaged        sound       1       0
# 208      damaged        sound       1       0
# 234      damaged        sound       1       0
# 256        sound      damaged       0       1
# 268        sound      damaged       0       1
# 284        sound      damaged       0       1
# 322        sound      damaged       0       1
# 336      damaged        sound       1       0
# 362      damaged        sound       1       0
# Incorrect predictions: 16 of 384

# %% [markdown]
# # PCA-SVM Test Result Analysis
#
# This section repeats the same test-result analyses for `reports/tables/pca_svm_test_predictions.csv`. It uses `data/splits` for the split sample summaries.

# %%
SVM_PREDICTIONS_CSV = TABLE_DIR / 'pca_svm_test_predictions.csv'
SVM_SPLITS_DIR = PROJECT_ROOT / 'data' / 'splits'

svm_df = pd.read_csv(SVM_PREDICTIONS_CSV)
svm_df['sample_id'] = svm_df['file'].astype(str) + ' | ' + svm_df['timepoint'].astype(str) + ' | ' + svm_df['dataset'].astype(str)
svm_df['microtec_id'] = svm_df['file'].str.extract(r'MICROTEC_(\d+)')[0]
svm_df['prefix2'] = svm_df['microtec_id'].str[:2]
svm_df['prefix3'] = svm_df['microtec_id'].str[:3]
svm_df['correct'] = svm_df['y_true'].eq(svm_df['y_pred'])

display(svm_df.head())
print('Rows:', len(svm_df))
print('Timepoints:', sorted(svm_df['timepoint'].astype(str).unique()))
print('Files:', svm_df['file'].nunique())
# Out:
#                                                 path  \
# 0  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
# 1  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
# 2  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
# 3  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
# 4  /srv/sysops/HIPPA/hanif/bruising_detection/dat...
#
#                                 file    group timepoint   dataset  y  label  \
# 0  MICROTEC_28009_processed_boxes.h5  SWIR_t0        t0  bruised1  0  sound
# 1  MICROTEC_28009_processed_boxes.h5  SWIR_t0        t0  bruised2  0  sound
# 2  MICROTEC_28009_processed_boxes.h5  SWIR_t0        t0  bruised3  0  sound
# 3  MICROTEC_28009_processed_boxes.h5  SWIR_t0        t0  bruised4  0  sound
# 4  MICROTEC_28009_processed_boxes.h5  SWIR_t0        t0    sound1  0  sound
#
#     box_shape crop_shape  bands  y_true  y_pred y_true_label y_pred_label  \
# 0  (160, 160)   (10, 10)    220       0       0        sound        sound
# 1  (160, 160)   (10, 10)    220       0       0        sound        sound
# 2  (160, 160)   (10, 10)    220       0       0        sound        sound
# 3  (160, 160)   (10, 10)    220       0       0        sound        sound
# 4  (160, 160)   (10, 10)    220       0       0        sound        sound
#
#                                            sample_id microtec_id prefix2  \
# 0  MICROTEC_28009_processed_boxes.h5 | t0 | bruised1       28009      28
# 1  MICROTEC_28009_processed_boxes.h5 | t0 | bruised2       28009      28
# 2  MICROTEC_28009_processed_boxes.h5 | t0 | bruised3       28009      28
# 3  MICROTEC_28009_processed_boxes.h5 | t0 | bruised4       28009      28
# 4    MICROTEC_28009_processed_boxes.h5 | t0 | sound1       28009      28
#
#   prefix3  correct
# 0     280     True
# 1     280     True
# 2     280     True
# 3     280     True
# 4     280     True
# Rows: 384
# Timepoints: ['t0', 't1', 't2', 't3']
# Files: 12

# %% [markdown]
# ## PCA-SVM Train/Validation/Test Sample Counts

# %%
SVM_SPLIT_SAMPLE_CSVS = {
    'train': SVM_SPLITS_DIR / 'train_samples.csv',
    'val': SVM_SPLITS_DIR / 'val_samples.csv',
    'test': SVM_SPLITS_DIR / 'test_samples.csv',
}

svm_split_rows = []
for split, path in SVM_SPLIT_SAMPLE_CSVS.items():
    split_df = pd.read_csv(path)
    svm_split_rows.append({
        'split': split,
        'n_files': split_df['file'].nunique(),
        'n_samples': len(split_df),
        'n_sound': int((split_df['y'] == 0).sum()),
        'n_bruised': int((split_df['y'] == 1).sum()),
    })

svm_split_summary = pd.DataFrame(svm_split_rows)
svm_total_files = int(svm_split_summary['n_files'].sum())
svm_total_samples = int(svm_split_summary['n_samples'].sum())
svm_total_sound = int(svm_split_summary['n_sound'].sum())
svm_total_bruised = int(svm_split_summary['n_bruised'].sum())
svm_split_summary['file_ratio'] = (svm_split_summary['n_files'] / svm_total_files).round(4)
svm_split_summary['sample_ratio'] = (svm_split_summary['n_samples'] / svm_total_samples).round(4)
svm_split_summary = pd.concat([
    svm_split_summary,
    pd.DataFrame([{
        'split': 'total',
        'n_files': svm_total_files,
        'n_samples': svm_total_samples,
        'n_sound': svm_total_sound,
        'n_bruised': svm_total_bruised,
        'file_ratio': 1.0,
        'sample_ratio': 1.0,
    }]),
], ignore_index=True)

display(svm_split_summary)
svm_split_summary.to_csv(TABLE_DIR / 'pca_svm_prediction_split_sample_summary.csv', index=False)
# Out:
#    split  n_files  n_samples  n_sound  n_bruised  file_ratio  sample_ratio
# 0  train       94       3008     1880       1128      0.7966        0.7966
# 1    val       12        384      240        144      0.1017        0.1017
# 2   test       12        384      240        144      0.1017        0.1017
# 3  total      118       3776     2360       1416      1.0000        1.0000

# %% [markdown]
# ## PCA-SVM Overall Confusion Matrix

# %%
svm_overall = pd.DataFrame([metric_row(svm_df, 'overall')])
display(svm_overall)
svm_overall.to_csv(TABLE_DIR / 'pca_svm_test_overall_metrics.csv', index=False)

svm_cm = confusion_matrix(svm_df['y_true'], svm_df['y_pred'], labels=LABELS)
fig, ax = plt.subplots(figsize=(4.5, 4))
plot_confusion(svm_cm, 'PCA-SVM overall confusion matrix', ax=ax)
plt.tight_layout()
save_figure(fig, 'pca_svm_overall_confusion.png')
plt.show()
# Out:
#      group    n  correct  incorrect  true_negative  false_positive  \
# 0  overall  384      366         18            236               4
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0              14            130                      144
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                           134    0.9531     0.9701  0.9028  0.9353

# %% [markdown]
# ## PCA-SVM Accuracy, Precision, Recall by Timepoint

# %%
svm_timepoint_metrics = metrics_by(svm_df, 'timepoint')
display(svm_timepoint_metrics)
svm_timepoint_metrics.to_csv(TABLE_DIR / 'pca_svm_test_metrics_by_timepoint.csv', index=False)
# Out:
#   group   n  correct  incorrect  true_negative  false_positive  \
# 0    t0  96       94          2             94               2
# 1    t1  96       87          9             47               1
# 2    t2  96       91          5             48               0
# 3    t3  96       94          2             47               1
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0               0              0                        0
# 1               8             40                       48
# 2               5             43                       48
# 3               1             47                       48
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                             2    0.9792     0.0000  0.0000  0.0000
# 1                            41    0.9062     0.9756  0.8333  0.8989
# 2                            43    0.9479     1.0000  0.8958  0.9451
# 3                            48    0.9792     0.9792  0.9792  0.9792

# %% [markdown]
# ## PCA-SVM Confusion Matrix per Timepoint

# %%
svm_timepoints = sorted(svm_df['timepoint'].astype(str).unique())
ncols = 2
nrows = int(np.ceil(len(svm_timepoints) / ncols))
fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4.2 * nrows))
axes = np.atleast_1d(axes).ravel()

for ax, tp in zip(axes, svm_timepoints):
    g = svm_df[svm_df['timepoint'].astype(str) == tp]
    cm = confusion_matrix(g['y_true'], g['y_pred'], labels=LABELS)
    plot_confusion(cm, f"PCA-SVM timepoint {str(tp).lstrip('t')}", ax=ax)

for ax in axes[len(svm_timepoints):]:
    ax.axis('off')

plt.tight_layout()
save_figure(fig, 'pca_svm_timepoint_confusion.png')
plt.show()

# %% [markdown]
# ## PCA-SVM Comparison: Warm vs Cold Condition

# %%
svm_compare_warm_cold = svm_df[svm_df['prefix2'].isin(['28', '29'])].copy()
svm_compare_warm_cold['comparison_group'] = svm_compare_warm_cold['prefix2'].map({'28': 'warm', '29': 'cold'})
svm_metrics_warm_cold = metrics_by(svm_compare_warm_cold, 'comparison_group')
svm_metrics_warm_cold = svm_metrics_warm_cold.set_index('group').loc[['warm', 'cold']].reset_index()
display(svm_metrics_warm_cold)
svm_metrics_warm_cold.to_csv(TABLE_DIR / 'pca_svm_test_compare_warm_cold.csv', index=False)

fig, ax = plt.subplots(figsize=(5.5, 4.0))
bars = ax.bar(svm_metrics_warm_cold['group'], svm_metrics_warm_cold['accuracy'], color=['#d98948', '#4c78a8'])
ax.set_ylim(0, 1)
ax.set_ylabel('Accuracy')
ax.set_title('PCA-SVM warm vs cold condition')
for bar, (_, row) in zip(bars, svm_metrics_warm_cold.iterrows()):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        max(row['accuracy'] - 0.12, 0.08),
        f"{row['correct']}/{row['n']} correct\nacc={row['accuracy']:.3f}",
        ha='center', va='center', color='black', fontsize=10,
        bbox={'facecolor': 'white', 'edgecolor': 'none', 'alpha': 0.85, 'pad': 3},
    )
plt.tight_layout()
save_figure(fig, 'pca_svm_warm_cold_accuracy.png')
plt.show()
# Out:
#   group    n  correct  incorrect  true_negative  false_positive  \
# 0  warm  192      184          8            117               3
# 1  cold  192      182         10            119               1
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0               5             67                       72
# 1               9             63                       72
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                            70    0.9583     0.9571  0.9306  0.9437
# 1                            64    0.9479     0.9844  0.8750  0.9265

# %% [markdown]
# ## PCA-SVM Comparison: Low, Medium, and High Impact

# %%
svm_compare_impact_groups = svm_df.copy()
svm_compare_impact_groups['comparison_group'] = svm_compare_impact_groups['prefix3'].map(impact_group)
svm_compare_impact_groups = svm_compare_impact_groups.dropna(subset=['comparison_group'])
svm_metrics_impact_groups = metrics_by(svm_compare_impact_groups, 'comparison_group')
svm_metrics_impact_groups = svm_metrics_impact_groups.set_index('group').loc[['low impact', 'medium impact', 'high impact']].reset_index()
display(svm_metrics_impact_groups)
svm_metrics_impact_groups.to_csv(TABLE_DIR / 'pca_svm_test_compare_impact_groups.csv', index=False)

fig, ax = plt.subplots(figsize=(6.8, 4.0))
colors = {'low impact': '#9b6fb0', 'medium impact': '#d8a03d', 'high impact': '#6f9e59'}
bars = ax.bar(
    svm_metrics_impact_groups['group'],
    svm_metrics_impact_groups['accuracy'],
    color=[colors[g] for g in svm_metrics_impact_groups['group']],
)
ax.set_ylim(0, 1)
ax.set_ylabel('Accuracy')
ax.set_title('PCA-SVM low, medium, and high impact')
for bar, (_, row) in zip(bars, svm_metrics_impact_groups.iterrows()):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        max(row['accuracy'] - 0.12, 0.08),
        f"{row['correct']}/{row['n']} correct\nacc={row['accuracy']:.3f}",
        ha='center', va='center', color='black', fontsize=10,
        bbox={'facecolor': 'white', 'edgecolor': 'none', 'alpha': 0.85, 'pad': 3},
    )
legend_handles = [plt.Rectangle((0, 0), 1, 1, color=colors[name], label=name) for name in ['low impact', 'medium impact', 'high impact']]
ax.legend(handles=legend_handles, title='Group', loc='center left', bbox_to_anchor=(1.02, 0.5), borderaxespad=0)
plt.tight_layout()
save_figure(fig, 'pca_svm_impact_accuracy.png')
plt.show()
# Out:
#            group    n  correct  incorrect  true_negative  false_positive  \
# 0     low impact  128      121          7             80               0
# 1  medium impact  128      120          8             78               2
# 2    high impact  128      125          3             78               2
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0               7             41                       48
# 1               6             42                       48
# 2               1             47                       48
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                            41    0.9453     1.0000  0.8542  0.9213
# 1                            44    0.9375     0.9545  0.8750  0.9130
# 2                            49    0.9766     0.9592  0.9792  0.9691

# %% [markdown]
# ## PCA-SVM Comparison: Low, Medium, and High Impact

# %%
svm_compare_three_groups = svm_df.copy()
svm_compare_three_groups['comparison_group'] = svm_compare_three_groups['prefix3'].map(impact_group_three_level)
svm_compare_three_groups = svm_compare_three_groups.dropna(subset=['comparison_group'])
svm_metrics_three_groups = metrics_by(svm_compare_three_groups, 'comparison_group')
svm_metrics_three_groups = svm_metrics_three_groups.set_index('group').loc[['low impact', 'medium impact', 'high impact']].reset_index()
display(svm_metrics_three_groups)
svm_metrics_three_groups.to_csv(TABLE_DIR / 'pca_svm_test_compare_three_impact_groups.csv', index=False)

print('Files per group')
display(svm_compare_three_groups.drop_duplicates('file').groupby(['comparison_group', 'prefix3']).size().rename('n_files').reset_index())

fig, ax = plt.subplots(figsize=(6.8, 4.0))
colors = {'low impact': '#9b6fb0', 'medium impact': '#d8a03d', 'high impact': '#6f9e59'}
bars = ax.bar(
    svm_metrics_three_groups['group'],
    svm_metrics_three_groups['accuracy'],
    color=[colors[g] for g in svm_metrics_three_groups['group']],
)
ax.set_ylim(0, 1)
ax.set_ylabel('Accuracy')
ax.set_title('PCA-SVM low, medium, and high impact')
for bar, (_, row) in zip(bars, svm_metrics_three_groups.iterrows()):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        max(row['accuracy'] - 0.12, 0.08),
        f"{row['correct']}/{row['n']} correct\nacc={row['accuracy']:.3f}",
        ha='center', va='center', color='black', fontsize=10,
        bbox={'facecolor': 'white', 'edgecolor': 'none', 'alpha': 0.85, 'pad': 3},
    )
plt.tight_layout()
save_figure(fig, 'pca_svm_three_impact_accuracy.png')
plt.show()
# Out:
#            group    n  correct  incorrect  true_negative  false_positive  \
# 0     low impact  128      121          7             80               0
# 1  medium impact  128      120          8             78               2
# 2    high impact  128      125          3             78               2
#
#    false_negative  true_positive  n_true_positive_samples  \
# 0               7             41                       48
# 1               6             42                       48
# 2               1             47                       48
#
#    n_predicted_positive_samples  accuracy  precision  recall      f1
# 0                            41    0.9453     1.0000  0.8542  0.9213
# 1                            44    0.9375     0.9545  0.8750  0.9130
# 2                            49    0.9766     0.9592  0.9792  0.9691
# Files per group
#    comparison_group prefix3  n_files
# 0       high impact     284        1
# 1       high impact     285        1
# 2       high impact     294        1
# 3       high impact     295        1
# 4        low impact     280        1
# 5        low impact     281        1
# 6        low impact     290        1
# 7        low impact     291        1
# 8     medium impact     282        1
# 9     medium impact     283        1
# 10    medium impact     292        1
# 11    medium impact     293        1

# %% [markdown]
# ## PCA-SVM Incorrect Predictions for Inspection

# %%
svm_errors = svm_df[~svm_df['correct']].copy()
svm_error_columns = ['file', 'microtec_id', 'timepoint', 'dataset', 'y_true_label', 'y_pred_label', 'y_true', 'y_pred']
display(svm_errors[svm_error_columns])
svm_errors[svm_error_columns].to_csv(TABLE_DIR / 'pca_svm_test_incorrect_predictions.csv', index=False)
print('Incorrect predictions:', len(svm_errors), 'of', len(svm_df))
# Out:
#                                   file microtec_id timepoint   dataset  \
# 11   MICROTEC_28009_processed_boxes.h5       28009        t1  bruised4
# 68   MICROTEC_28206_processed_boxes.h5       28206        t0    sound1
# 75   MICROTEC_28206_processed_boxes.h5       28206        t1  bruised4
# 76   MICROTEC_28206_processed_boxes.h5       28206        t1    sound1
# 83   MICROTEC_28206_processed_boxes.h5       28206        t2  bruised4
# 106  MICROTEC_28305_processed_boxes.h5       28305        t1  bruised3
# 163  MICROTEC_28507_processed_boxes.h5       28507        t0  bruised4
# 168  MICROTEC_28507_processed_boxes.h5       28507        t1  bruised1
# 203  MICROTEC_29006_processed_boxes.h5       29006        t1  bruised4
# 210  MICROTEC_29006_processed_boxes.h5       29006        t2  bruised3
# 232  MICROTEC_29100_processed_boxes.h5       29100        t1  bruised1
# 240  MICROTEC_29100_processed_boxes.h5       29100        t2  bruised1
# 243  MICROTEC_29100_processed_boxes.h5       29100        t2  bruised4
# 248  MICROTEC_29100_processed_boxes.h5       29100        t3  bruised1
# 266  MICROTEC_29207_processed_boxes.h5       29207        t1  bruised3
# 267  MICROTEC_29207_processed_boxes.h5       29207        t1  bruised4
# 304  MICROTEC_29309_processed_boxes.h5       29309        t2  bruised1
# 349  MICROTEC_29405_processed_boxes.h5       29405        t3    sound2
#
#     y_true_label y_pred_label  y_true  y_pred
# 11       damaged        sound       1       0
# 68         sound      damaged       0       1
# 75       damaged        sound       1       0
# 76         sound      damaged       0       1
# 83       damaged        sound       1       0
# 106      damaged        sound       1       0
# 163        sound      damaged       0       1
# 168      damaged        sound       1       0
# 203      damaged        sound       1       0
# 210      damaged        sound       1       0
# 232      damaged        sound       1       0
# 240      damaged        sound       1       0
# 243      damaged        sound       1       0
# 248      damaged        sound       1       0
# 266      damaged        sound       1       0
# 267      damaged        sound       1       0
# 304      damaged        sound       1       0
# 349        sound      damaged       0       1
# Incorrect predictions: 18 of 384
